# %%
import glob
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
p = Path("data/data/20230302_avantes_spectrometer_third_dataset/")
file, = list(p.glob("C01C_PVC_FDP.csv"))

# %%
wave = np.loadtxt(file, skiprows=6, delimiter=",", usecols=[0])
spec = np.loadtxt(file, skiprows=6, delimiter=",", usecols=[1,2,3,4,5])

# %%
plt.plot(wave,spec)
